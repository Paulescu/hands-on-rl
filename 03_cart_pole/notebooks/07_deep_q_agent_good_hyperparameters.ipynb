# %% [markdown]
# # 07 Deep Q agent with good hyper-parameters
#
# #### 👉 Let's use a neural network model to approximate the Q function.
#
# #### 👉Neural networks are usually highly-parametric models that are able to fit complex patterns between the input features and the target.
#
# #### 👉 The type of neural network we will use is a Multi Layer Perceptron (MLP).
#
# #### 👉MLPs are stacks of linear models, interleaved with so called activation functions.

# %% [markdown]
# ![nn](https://github.com/Paulescu/hands-on-rl/blob/main/03_cart_pole/images/neural_net.jpg?raw=true)

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Environment 🌎

# %%
import gym
env = gym.make('CartPole-v1')

# %% [markdown]
# ## Hyperparameters

# %%
# Good hyper-parameters
# make you feel great!
hparams = {
    'learning_rate': 0.00016151809562265122,
    'discount_factor': 0.99,
    'batch_size': 32,
    'memory_size': 10000,
    'freq_steps_train': 8,
    'freq_steps_update_target': 10,
    'n_steps_warm_up_memory': 1000,
    'n_gradient_steps': 16,
    'nn_hidden_layers': [256, 256],
    'max_grad_norm': 10,
    'normalize_state': False,
    'epsilon_start': 0.9,
    'epsilon_end': 0.14856584122699473,
    'steps_epsilon_decay': 10000,
}

# Lapadula: New hparams from saved_agents/CartPole-v1/298/hparams.json
hparams = {"learning_rate": 0.00045095481485457226, "discount_factor": 0.99, "batch_size": 16, "memory_size": 100000, "freq_steps_update_target": 10, "n_steps_warm_up_memory": 1000, "freq_steps_train": 8, "n_gradient_steps": 16, "nn_hidden_layers": [256, 256], "max_grad_norm": 1, "normalize_state": False, "epsilon_start": 0.9, "epsilon_end": 0.06286625175600052, "steps_epsilon_decay": 10000}

SEED = 2386916045

# %% [markdown]
# ## ⚠️ Fix random seeds

# %%
from src.utils import set_seed
set_seed(env, SEED)

# %% [markdown]
# ## Deep Q-Agent

# %%
from src.q_agent import QAgent
agent = QAgent(env, **hparams)
# Out:
# 67,586 parameters

# %% [markdown]
# ## Train the agent 🏋️

# %%
from src.loops import train
train(agent, env, n_episodes=200)
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████▋| 199/200 [03:33<00:04,  4.84s/it]
#   0%|                                                                                    | 0/100 [00:00<?, ?it/s]
#   2%|█▌                                                                          | 2/100 [00:00<00:08, 11.23it/s]
#   4%|███                                                                         | 4/100 [00:00<00:08, 10.95it/s]
#   6%|████▌                                                                       | 6/100 [00:00<00:08, 11.04it/s]
#   8%|██████                                                                      | 8/100 [00:00<00:08, 10.99it/s]
#  10%|███████▌                                                                   | 10/100 [00:00<00:08, 10.43it/s]
#  12%|█████████                                                                  | 12/100 [00:01<00:08, 10.25it/s]
#  14%|██████████▌                                                                | 14/100 [00:01<00:08, 10.20it/s]
#  16%|████████████                                                               | 16/100 [00:01<00:08, 10.32it/s]
#  18%|█████████████▌                                                             | 18/100 [00:01<00:08, 10.20it/s]
#  20%|███████████████                                                            | 20/100 [00:01<00:07, 10.25it/s]
#  22%|████████████████▌                                                          | 22/100 [00:02<00:07, 10.28it/s]
#  24%|██████████████████                                                         | 24/100 [00:02<00:07, 10.36it/s]
#  26%|███████████████████▌                                                       | 26/100 [00:02<00:07, 10.39it/s]
#  28%|█████████████████████                                                      | 28/100 [00:02<00:06, 10.50it/s]
#  30%|██████████████████████▌                                                    | 30/100 [00:02<00:06, 10.53it/s]
#  32%|████████████████████████                                                   | 32/100 [00:03<00:06, 10.56it/s]
#  34%|█████████████████████████▌                                                 | 34/100 [00:03<00:06, 10.31it/s]
#  36%|███████████████████████████                                                | 36/100 [00:03<00:06, 10.12it/s]
#  38%|████████████████████████████▌                                              | 38/100 [00:03<00:06, 10.31it/s]
#  40%|██████████████████████████████                                             | 40/100 [00:03<00:05, 10.61it/s]
#  42%|███████████████████████████████▌                                           | 42/100 [00:04<00:05, 10.83it/s]
#  44%|█████████████████████████████████                                          | 44/100 [00:04<00:05, 10.95it/s]
#  46%|██████████████████████████████████▌                                        | 46/100 [00:04<00:04, 11.11it/s]
#  48%|████████████████████████████████████                                       | 48/100 [00:04<00:04, 11.23it/s]
#  50%|█████████████████████████████████████▌                                     | 50/100 [00:04<00:04, 11.33it/s]
#  52%|███████████████████████████████████████                                    | 52/100 [00:04<00:04, 11.32it/s]
#  54%|████████████████████████████████████████▌                                  | 54/100 [00:05<00:04, 11.33it/s]
#  56%|██████████████████████████████████████████                                 | 56/100 [00:05<00:03, 11.36it/s]
#  58%|███████████████████████████████████████████▌                               | 58/100 [00:05<00:03, 11.41it/s]
#  60%|█████████████████████████████████████████████                              | 60/100 [00:05<00:03, 11.40it/s]
#  62%|██████████████████████████████████████████████▌                            | 62/100 [00:05<00:03, 11.43it/s]
#  64%|████████████████████████████████████████████████                           | 64/100 [00:05<00:03, 11.45it/s]
#  66%|█████████████████████████████████████████████████▌                         | 66/100 [00:06<00:02, 11.39it/s]
#  68%|███████████████████████████████████████████████████                        | 68/100 [00:06<00:02, 11.41it/s]
#  70%|████████████████████████████████████████████████████▌                      | 70/100 [00:06<00:02, 11.45it/s]
#  72%|██████████████████████████████████████████████████████                     | 72/100 [00:06<00:02, 11.46it/s]
#  74%|███████████████████████████████████████████████████████▌                   | 74/100 [00:06<00:02, 11.29it/s]
#  76%|█████████████████████████████████████████████████████████                  | 76/100 [00:07<00:02, 10.99it/s]
#  78%|██████████████████████████████████████████████████████████▌                | 78/100 [00:07<00:02, 10.98it/s]
#  80%|████████████████████████████████████████████████████████████               | 80/100 [00:07<00:01, 10.98it/s]
#  82%|█████████████████████████████████████████████████████████████▍             | 82/100 [00:07<00:01, 10.90it/s]
#  84%|███████████████████████████████████████████████████████████████            | 84/100 [00:07<00:01, 11.02it/s]
#  86%|████████████████████████████████████████████████████████████████▌          | 86/100 [00:07<00:01, 11.27it/s]
#  88%|██████████████████████████████████████████████████████████████████         | 88/100 [00:08<00:01, 11.02it/s]
#  90%|███████████████████████████████████████████████████████████████████▌       | 90/100 [00:08<00:00, 11.28it/s]
#  92%|█████████████████████████████████████████████████████████████████████      | 92/100 [00:08<00:00, 11.49it/s]
#  94%|██████████████████████████████████████████████████████████████████████▌    | 94/100 [00:08<00:00, 11.60it/s]
#  96%|████████████████████████████████████████████████████████████████████████   | 96/100 [00:08<00:00, 11.71it/s]
#  98%|█████████████████████████████████████████████████████████████████████████▌ | 98/100 [00:08<00:00, 11.80it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 100/100 [00:09<00:00, 10.99it/s]
# 100%|██████████████████████████████████████████████████████████████████████████| 200/200 [03:46<00:00,  1.13s/it]
# Reward mean: 500.00, std: 0.00
# Num steps mean: 500.00, std: 0.00

# %% [markdown]
# ## Evaluate the agent ⏱️

# %%
from src.loops import evaluate
rewards, steps = evaluate(
    agent, env,
    n_episodes=1000,
    epsilon=0.00
)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████| 1000/1000 [01:42<00:00,  9.74it/s]

# %%
import numpy as np
reward_avg = np.array(rewards).mean()
reward_std = np.array(rewards).std()
print(f'Reward average {reward_avg:.2f}, std {reward_std:.2f}')
# Out:
# Reward average 500.00, std 0.00

# %% [markdown]
# ## Let's see how far we got in each attempt

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig, ax = plt.subplots(figsize = (10, 4))
ax.set_title("Rewards")    
pd.Series(rewards).plot(kind='hist', bins=100)

plt.show()

# %% [markdown]
# ## Let's see our agent in action 🎬

# %%
# Workaround for pygame error: "error: No available video device"
# See https://stackoverflow.com/questions/15933493/pygame-error-no-available-video-device?rq=1
# This is probably needed only for Linux
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"

from src.viz import show_video
show_video(agent, env, sleep_sec=0.01, seed=123)
