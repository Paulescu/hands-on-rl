# %% [markdown]
# # 03 Vanilla Policy Gradient with rewards as weights
#
# #### 👉🏽 The policy network will have the following architecture:
#
# <img src="https://github.com/Paulescu/hands-on-rl/blob/main/04_lunar_lander/images/policy_network.svg?raw=True" width="300"/>
#
# #### 👉🏽 And we will use the rewards to compute the weights in the policy gradient formula.

# %%
# %load_ext autoreload
# %autoreload 2
# %pylab inline
# %config InlineBackend.figure_format = 'svg'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Environment 🚀🌙

# %%
ENV_NAME = 'LunarLander-v2'

# %% [markdown]
# ## Create agent and set hyperparameters

# %%
from src.vpg_agent import VPGAgent

agent = VPGAgent(
    env_name=ENV_NAME,
    learning_rate=3e-3,
    hidden_layers=[16, 16],
    gradient_weights='rewards',
)
# Out:
# Policy network with 484 parameters
# Sequential(
#   (0): Linear(in_features=8, out_features=16, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=16, out_features=16, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=16, out_features=4, bias=True)
# )

# %% [markdown]
# ## Tensorboard logger to see training metrics

# %%
from src.utils import get_agent_id
agent_id = get_agent_id(ENV_NAME)
print(f'agent_id = {agent_id}')

# tensorboard logger to see training curves
from src.utils import get_logger, get_model_path
logger = get_logger(env_name=ENV_NAME, agent_id=agent_id)

# path to save policy network weights and hyperparameters
model_path = get_model_path(env_name=ENV_NAME, agent_id=agent_id)
# Out:
# agent_id = 25

# %% [markdown]
# ## Training 🏋️

# %%
agent.train(
    n_policy_updates=5000,
    batch_size=256,
    logger=logger,
    model_path=model_path,
)
# Out:
# epoch:   0 	 loss: -215.984 	 reward: -157.047
# epoch:   1 	 loss: -107.061 	 reward: -76.507
# epoch:   2 	 loss: -205.527 	 reward: -139.893
# epoch:   3 	 loss: -199.578 	 reward: -145.954
# epoch:   4 	 loss: -155.837 	 reward: -111.409
# epoch:   5 	 loss: -102.618 	 reward: -73.663
# epoch:   6 	 loss: -201.771 	 reward: -149.592
# epoch:   7 	 loss: -162.250 	 reward: -117.340
# epoch:   8 	 loss: -132.877 	 reward: -96.847
# epoch:   9 	 loss: -435.072 	 reward: -325.352
# 100%|████████████████████████| 100/100 [00:03<00:00, 29.74it/s]
# Best model! Average reward = -183.38, Success rate = 0.00%
# epoch:  10 	 loss: -149.023 	 reward: -108.603
# epoch:  11 	 loss: -311.351 	 reward: -224.884
# epoch:  12 	 loss: -252.932 	 reward: -187.929
# epoch:  13 	 loss: -159.632 	 reward: -115.389
# epoch:  14 	 loss: -97.617 	 reward: -74.052
# epoch:  15 	 loss: -372.149 	 reward: -271.925
# epoch:  16 	 loss: -198.433 	 reward: -145.436
# epoch:  17 	 loss: -275.652 	 reward: -197.907
# epoch:  18 	 loss: -456.311 	 reward: -330.963
# epoch:  19 	 loss: -155.368 	 reward: -112.104
# 100%|████████████████████████| 100/100 [00:03<00:00, 29.13it/s]
# Best model! Average reward = -175.06, Success rate = 0.00%
# epoch:  20 	 loss: -225.443 	 reward: -163.335
# epoch:  21 	 loss: -116.502 	 reward: -83.259
# epoch:  22 	 loss: -119.350 	 reward: -85.642
# epoch:  23 	 loss: -462.430 	 reward: -336.907
# epoch:  24 	 loss: -145.332 	 reward: -106.624
# epoch:  25 	 loss: -187.039 	 reward: -135.333
# epoch:  26 	 loss: -355.077 	 reward: -258.177
# epoch:  27 	 loss: -122.593 	 reward: -89.176
# epoch:  28 	 loss: -307.893 	 reward: -221.645
# epoch:  29 	 loss: -105.638 	 reward: -76.690
# 100%|████████████████████████| 100/100 [00:03<00:00, 29
01it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 agent.train(
#       2     n_policy_updates=1000,
#       3     batch_size=64,
#       4     logger=logger,
#       5     model_path=model_path,
#       6 )
#
# File ~/src/online-courses/hands-on-rl/04_lunar_lander/src/vpg_agent.py:114, in VPGAgent.train(self, n_policy_updates, batch_size, logger, model_path, seed, freq_eval_in_epochs)
#     112 # evaluate the agent on a fixed set of 100 episodes
#     113 if (i + 1) % freq_eval_in_epochs == 0:
# --> 114     rewards, success = self.evaluate(n_episodes=100)
#     116     avg_reward = np.mean(rewards)
#     117     avg_success_rate = np.mean(success)
#
# File ~/src/online-courses/hands-on-rl/04_lunar_lander/src/vpg_agent.py:145, in VPGAgent.evaluate(self, n_episodes, seed)
#     141 while not done:
#     143     action = self.act(torch.as_tensor(state, dtype=torch.float32))
# --> 145     next_state, reward, done, info = self.env.step(action)
#     146     rewards += reward
#     148     state = next_state
#
# File ~/src/online-courses/hands-on-rl/04_lunar_lander/.venv/lib/python3.8/site-packages/gym/wrappers/time_limit.py:16, in TimeLimit.step(self, action)
#      14 def step(self, action):
#      15     assert self._elapsed_steps is not None, "Cannot call env.step() before calling reset()"
# ---> 16     observation, reward, done, info = self.env.step(action)
#      17     self._elapsed_steps += 1
#      18     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/src/online-courses/hands-on-rl/04_lunar_lander/.venv/lib/python3.8/site-packages/gym/envs/box2d/lunar_lander.py:292, in LunarLander.step(self, action)
#     290 ox = tip[0] * dispersion[0] + side[0] * (3 * dispersion[1] + direction * SIDE_ENGINE_AWAY/SCALE)
#     291 oy = -tip[1] * dispersion[0] - side[1] * (3 * dispersion[1] + direction * SIDE_ENGINE_AWAY/SCALE)
# --> 292 impulse_pos = (self.lander.position[0] + ox - tip[0] * 17/SCALE,
#     293                self.lander.position[1] + oy + tip[1] * SIDE_ENGINE_HEIGHT/SCALE)
#     294 p = self._create_particle(0.7, impulse_pos[0], impulse_pos[1], s_power)
#     295 p.ApplyLinearImpulse((ox * SIDE_ENGINE_POWER * s_power, oy * SIDE_ENGINE_POWER * s_power),
#     296                      impulse_pos
#     297                      , True)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Evaluate the agent ⏱️

# %%
rewards, success = agent.evaluate(n_episodes=100)
# Out:
# Policy network with 836 parameters
# Sequential(
#   (0): Linear(in_features=8, out_features=64, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=64, out_features=4, bias=True)
# )

# %% [markdown]
# ### Average reward

# %%
import numpy as np
reward_avg = np.array(rewards).mean()
reward_std = np.array(rewards).std()
print(f'Reward average {reward_avg:.2f}, std {reward_std:.2f}')

success_rate = np.array(success).mean()
print(f'Succes rate = {success_rate:.2%}')
# Out:
# Reward average 236.12, std 76.28

# %% [markdown]
# ## Reward distribution

# %%
import matplotlib.pyplot as plt
import pandas as pd

fig, ax = plt.subplots(figsize = (10, 4))
ax.set_title("Rewards")    
pd.Series(rewards).plot(kind='hist', bins=100)

plt.show()

# %% [markdown]
# ## Let's see our agent in action 🎬

# %%
# Workaround for pygame error: "error: No available video device"
# See https://stackoverflow.com/questions/15933493/pygame-error-no-available-video-device?rq=1
# This is probably needed only for Linux
import os
os.environ["SDL_VIDEODRIVER"] = "dummy"
from src.viz import show_video

show_video(agent, env, sleep_sec=0.01, seed=12345)
